# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/daniellebeddoe/Desktop/UofHart/QNT755/NHANEs.csv')

# %%
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None) 

df.head()
# Out:
#   SurveyYr     ID  Gender  Age AgeDecade  AgeMonths  Race1 Race3    Education MaritalStatus     HHIncome  HHIncomeMid  Poverty  HomeRooms HomeOwn        Work  Weight  Length  HeadCirc  Height    BMI BMICatUnder20yrs       BMI_WHO  Pulse  BPSysAve  BPDiaAve  BPSys1  BPDia1  BPSys2  BPDia2  BPSys3  BPDia3  Testosterone  DirectChol  TotChol  UrineVol1  UrineFlow1  UrineVol2  UrineFlow2 Diabetes  DiabetesAge  HealthGen  DaysPhysHlthBad  DaysMentHlthBad LittleInterest Depressed  nPregnancies  nBabies  Age1stBaby  SleepHrsNight SleepTrouble PhysActive  PhysActiveDays TVHrsDay CompHrsDay  TVHrsDayChild  CompHrsDayChild Alcohol12PlusYr  AlcoholDay  AlcoholYear SmokeNow Smoke100   Smoke100n  SmokeAge Marijuana  AgeFirstMarij RegularMarij  AgeRegMarij HardDrugs SexEver  SexAge  SexNumPartnLife  SexNumPartYear SameSex SexOrientation
# ...

# %%
df.shape
# Out:
# (10000, 75)

# %%
df.columns
# Out:
# Index(['SurveyYr', 'ID', 'Gender', 'Age', 'AgeDecade', 'AgeMonths', 'Race1',
#        'Race3', 'Education', 'MaritalStatus', 'HHIncome', 'HHIncomeMid',
#        'Poverty', 'HomeRooms', 'HomeOwn', 'Work', 'Weight', 'Length',
#        'HeadCirc', 'Height', 'BMI', 'BMICatUnder20yrs', 'BMI_WHO', 'Pulse',
#        'BPSysAve', 'BPDiaAve', 'BPSys1', 'BPDia1', 'BPSys2', 'BPDia2',
#        'BPSys3', 'BPDia3', 'Testosterone', 'DirectChol', 'TotChol',
#        'UrineVol1', 'UrineFlow1', 'UrineVol2', 'UrineFlow2', 'Diabetes',
#        'DiabetesAge', 'HealthGen', 'DaysPhysHlthBad', 'DaysMentHlthBad',
#        'LittleInterest', 'Depressed', 'nPregnancies', 'nBabies', 'Age1stBaby',
#        'SleepHrsNight', 'SleepTrouble', 'PhysActive', 'PhysActiveDays',
#        'TVHrsDay', 'CompHrsDay', 'TVHrsDayChild', 'CompHrsDayChild',
#        'Alcohol12PlusYr', 'AlcoholDay', 'AlcoholYear', 'SmokeNow', 'Smoke100',
#        'Smoke100n', 'SmokeAge', 'Marijuana', 'AgeFirstMarij', 'RegularMarij',
# ...

# %%
df.dtypes
# Out:
# SurveyYr             object
# ID                    int64
# Gender               object
# Age                   int64
# AgeDecade            object
# AgeMonths           float64
# Race1                object
# Race3                object
# Education            object
# MaritalStatus        object
# HHIncome             object
# HHIncomeMid         float64
# Poverty             float64
# HomeRooms           float64
# HomeOwn              object
# Work                 object
# Weight              float64
# Length              float64
# HeadCirc            float64
# Height              float64
# BMI                 float64
# BMICatUnder20yrs     object
# BMI_WHO              object
# Pulse               float64
# BPSysAve            float64
# BPDiaAve            float64
# BPSys1              float64
# BPDia1              float64
# BPSys2              float64
# BPDia2              float64
# BPSys3              float64
# BPDia3              float64
# Testosterone        float64
# ...

# %%
df_numeric = df.select_dtypes(include = ['int64','float64'])

# %%
df_numeric.shape
# Out:
# (10000, 45)

# %%
df_category = df.select_dtypes(include = ['object'])

# %%
df_category.shape
# Out:
# (10000, 30)

# %%
df_numeric.describe()
# Out:
#                 ID           Age    AgeMonths    HHIncomeMid      Poverty    HomeRooms       Weight      Length   HeadCirc       Height          BMI        Pulse     BPSysAve     BPDiaAve       BPSys1       BPDia1       BPSys2       BPDia2       BPSys3       BPDia3  Testosterone   DirectChol      TotChol    UrineVol1   UrineFlow1    UrineVol2   UrineFlow2  DiabetesAge  DaysPhysHlthBad  DaysMentHlthBad  nPregnancies      nBabies   Age1stBaby  SleepHrsNight  PhysActiveDays  TVHrsDayChild  CompHrsDayChild   AlcoholDay  AlcoholYear     SmokeAge  AgeFirstMarij  AgeRegMarij       SexAge  SexNumPartnLife  SexNumPartYear
# ...

# %%
df_numeric.describe().to_excel('/Users/daniellebeddoe/Desktop/UofHart/QNT755/numeric.xlsx')

# %%
df_category.describe()
# Out:
#        SurveyYr  Gender AgeDecade  Race1  Race3    Education MaritalStatus    HHIncome HomeOwn     Work BMICatUnder20yrs       BMI_WHO Diabetes HealthGen LittleInterest Depressed SleepTrouble PhysActive TVHrsDay CompHrsDay Alcohol12PlusYr SmokeNow Smoke100   Smoke100n Marijuana RegularMarij HardDrugs SexEver SameSex SexOrientation
# count     10000   10000      9667  10000   5000         7221          7231        9189    9937     7771             1274          9603     9858      7539           6667      6673         7772       8326     4859       4863            6580     3211     7235        7235      4941         4941      5765    5767    5768           4842
# ...

# %%
df_category.describe().to_excel('/Users/daniellebeddoe/Desktop/UofHart/QNT755/category.xlsx')

# %%
#percentage for missing values
((df_numeric.isnull().sum())/10000)*100
# Out:
# ID                  0.00
# Age                 0.00
# AgeMonths          50.38
# HHIncomeMid         8.11
# Poverty             7.26
# HomeRooms           0.69
# Weight              0.78
# Length             94.57
# HeadCirc           99.12
# Height              3.53
# BMI                 3.66
# Pulse              14.37
# BPSysAve           14.49
# BPDiaAve           14.49
# BPSys1             17.63
# BPDia1             17.63
# BPSys2             16.47
# BPDia2             16.47
# BPSys3             16.35
# BPDia3             16.35
# Testosterone       58.74
# DirectChol         15.26
# TotChol            15.26
# UrineVol1           9.87
# UrineFlow1         16.03
# UrineVol2          85.22
# UrineFlow2         85.24
# DiabetesAge        93.71
# DaysPhysHlthBad    24.68
# DaysMentHlthBad    24.66
# nPregnancies       73.96
# nBabies            75.84
# Age1stBaby         81.16
# SleepHrsNight      22.45
# PhysActiveDays     53.37
# TVHrsDayChild      93.47
# CompHrsDayChild    93.47
# ...

# %%
df_numeric.columns
# Out:
# Index(['ID', 'Age', 'AgeMonths', 'HHIncomeMid', 'Poverty', 'HomeRooms',
#        'Weight', 'Length', 'HeadCirc', 'Height', 'BMI', 'Pulse', 'BPSysAve',
#        'BPDiaAve', 'BPSys1', 'BPDia1', 'BPSys2', 'BPDia2', 'BPSys3', 'BPDia3',
#        'Testosterone', 'DirectChol', 'TotChol', 'UrineVol1', 'UrineFlow1',
#        'UrineVol2', 'UrineFlow2', 'DiabetesAge', 'DaysPhysHlthBad',
#        'DaysMentHlthBad', 'nPregnancies', 'nBabies', 'Age1stBaby',
#        'SleepHrsNight', 'PhysActiveDays', 'TVHrsDayChild', 'CompHrsDayChild',
#        'AlcoholDay', 'AlcoholYear', 'SmokeAge', 'AgeFirstMarij', 'AgeRegMarij',
#        'SexAge', 'SexNumPartnLife', 'SexNumPartYear'],
#       dtype='object')

# %%
#percentage for missing values
((df_category.isnull().sum())/10000)*100
# Out:
# SurveyYr             0.00
# Gender               0.00
# AgeDecade            3.33
# Race1                0.00
# Race3               50.00
# Education           27.79
# MaritalStatus       27.69
# HHIncome             8.11
# HomeOwn              0.63
# Work                22.29
# BMICatUnder20yrs    87.26
# BMI_WHO              3.97
# Diabetes             1.42
# HealthGen           24.61
# LittleInterest      33.33
# Depressed           33.27
# SleepTrouble        22.28
# PhysActive          16.74
# TVHrsDay            51.41
# CompHrsDay          51.37
# Alcohol12PlusYr     34.20
# SmokeNow            67.89
# Smoke100            27.65
# Smoke100n           27.65
# Marijuana           50.59
# RegularMarij        50.59
# HardDrugs           42.35
# SexEver             42.33
# SameSex             42.32
# SexOrientation      51.58
# dtype: float64

# %%
df_category.columns
# Out:
# Index(['SurveyYr', 'Gender', 'AgeDecade', 'Race1', 'Race3', 'Education',
#        'MaritalStatus', 'HHIncome', 'HomeOwn', 'Work', 'BMICatUnder20yrs',
#        'BMI_WHO', 'Diabetes', 'HealthGen', 'LittleInterest', 'Depressed',
#        'SleepTrouble', 'PhysActive', 'TVHrsDay', 'CompHrsDay',
#        'Alcohol12PlusYr', 'SmokeNow', 'Smoke100', 'Smoke100n', 'Marijuana',
#        'RegularMarij', 'HardDrugs', 'SexEver', 'SameSex', 'SexOrientation'],
#       dtype='object')

# %%
#new dataframe selected with variables where columns have  missing values less than 30%
df2 = df[['Age','HHIncomeMid', 'Poverty', 'HomeRooms',
       'Weight', 'Height', 'BMI', 'Pulse', 'BPSysAve',
       'BPDiaAve', 'BPSys1', 'BPDia1', 'BPSys2', 'BPDia2', 'BPSys3', 'BPDia3',
        'DirectChol', 'TotChol', 'UrineVol1', 'UrineFlow1',
        'DaysPhysHlthBad',
       'DaysMentHlthBad','SleepHrsNight',
        'Gender', 'AgeDecade', 'Race1', 'Education',
       'MaritalStatus', 'HHIncome', 'HomeOwn', 'Work',
       'BMI_WHO', 'Diabetes', 'HealthGen',
       'SleepTrouble', 'PhysActive','Smoke100', 'Smoke100n']]

# %%
df2.shape
# Out:
# (10000, 38)

# %%
((df2.isnull().sum())/10000)*100
# Out:
# Age                 0.00
# HHIncomeMid         8.11
# Poverty             7.26
# HomeRooms           0.69
# Weight              0.78
# Height              3.53
# BMI                 3.66
# Pulse              14.37
# BPSysAve           14.49
# BPDiaAve           14.49
# BPSys1             17.63
# BPDia1             17.63
# BPSys2             16.47
# BPDia2             16.47
# BPSys3             16.35
# BPDia3             16.35
# DirectChol         15.26
# TotChol            15.26
# UrineVol1           9.87
# UrineFlow1         16.03
# DaysPhysHlthBad    24.68
# DaysMentHlthBad    24.66
# SleepHrsNight      22.45
# Gender              0.00
# AgeDecade           3.33
# Race1               0.00
# Education          27.79
# MaritalStatus      27.69
# HHIncome            8.11
# HomeOwn             0.63
# Work               22.29
# BMI_WHO             3.97
# Diabetes            1.42
# HealthGen          24.61
# SleepTrouble       22.28
# PhysActive         16.74
# Smoke100           27.65
# ...

# %%
#fill in missing values using mode for categorical variables
df2['Gender'].fillna(df2['Gender'].mode()[0],inplace=True)
df2['AgeDecade'].fillna(df2['AgeDecade'].mode()[0],inplace=True)
df2['Race1'].fillna(df2['Race1'].mode()[0],inplace=True)
df2['Education'].fillna(df2['Education'].mode()[0],inplace=True)
df2['MaritalStatus'].fillna(df2['MaritalStatus'].mode()[0],inplace=True)
df2['HHIncome'].fillna(df2['HHIncome'].mode()[0],inplace=True)
df2['HomeOwn'].fillna(df2['HomeOwn'].mode()[0],inplace=True)
df2['Work'].fillna(df2['Work'].mode()[0],inplace=True)
df2['BMI_WHO'].fillna(df2['BMI_WHO'].mode()[0],inplace=True)
df2['Diabetes'].fillna(df2['Diabetes'].mode()[0],inplace=True)
df2['HealthGen'].fillna(df2['HealthGen'].mode()[0],inplace=True)
df2['SleepTrouble'].fillna(df2['SleepTrouble'].mode()[0],inplace=True)
df2['PhysActive'].fillna(df2['PhysActive'].mode()[0],inplace=True)
df2['Smoke100'].fillna(df2['Smoke100'].mode()[0],inplace=True)
df2['Smoke100n'].fillna(df2['Smoke100n'].mode()[0],inplace=True)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df2['Age'].fillna(df2['Age'].mean(),inplace=True)
df2['HHIncomeMid'].fillna(df2['HHIncomeMid'].mean(),inplace=True)

# %%
#fill in missing values using mean for numeric variables
df2['HHIncomeMid'].fillna(df2['HHIncomeMid'].mean(),inplace=True)
df2['Poverty'].fillna(df2['Poverty'].mean(),inplace=True)
df2['HomeRooms'].fillna(df2['HomeRooms'].mean(),inplace=True)
df2['Weight'].fillna(df2['Weight'].mean(),inplace=True)
df2['Height'].fillna(df2['Height'].mean(),inplace=True)
df2['BMI'].fillna(df2['BMI'].mean(),inplace=True)
df2['Pulse'].fillna(df2['Pulse'].mean(),inplace=True)
df2['BPSysAve'].fillna(df2['BPSysAve'].mean(),inplace=True)
df2['BPDiaAve'].fillna(df2['BPDiaAve'].mean(),inplace=True)
df2['BPSys1'].fillna(df2['BPSys1'].mean(),inplace=True)
df2['BPDia1'].fillna(df2['BPDia1'].mean(),inplace=True)
df2['BPSys2'].fillna(df2['BPSys2'].mean(),inplace=True)
df2['BPSys1'].fillna(df2['BPSys1'].mean(),inplace=True)
df2['BPSys3'].fillna(df2['BPSys3'].mean(),inplace=True)
df2['BPDia3'].fillna(df2['BPDia3'].mean(),inplace=True)
df2['BPDia2'].fillna(df2['BPDia2'].mean(),inplace=True)
df2['DirectChol'].fillna(df2['DirectChol'].mean(),inplace=True)
df2['TotChol'].fillna(df2['TotChol'].mean(),inplace=True)
df2['UrineVol1'].fillna(df2['UrineVol1'].mean(),inplace=True)
df2['UrineFlow1'].fillna(df2['UrineFlow1'].mean(),inplace=True)
df2['DaysPhysHlthBad'].fillna(df2['DaysPhysHlthBad'].mean(),inplace=True)
df2['DaysMentHlthBad'].fillna(df2['DaysMentHlthBad'].mean(),inplace=True)
df2['SleepHrsNight'].fillna(df2['SleepHrsNight'].mean(),inplace=True)

# %%
df2.dtypes
# Out:
# Age                  int64
# HHIncomeMid        float64
# Poverty            float64
# HomeRooms          float64
# Weight             float64
# Height             float64
# BMI                float64
# Pulse              float64
# BPSysAve           float64
# BPDiaAve           float64
# BPSys1             float64
# BPDia1             float64
# BPSys2             float64
# BPDia2             float64
# BPSys3             float64
# BPDia3             float64
# DirectChol         float64
# TotChol            float64
# UrineVol1          float64
# UrineFlow1         float64
# DaysPhysHlthBad    float64
# DaysMentHlthBad    float64
# SleepHrsNight      float64
# Gender              object
# AgeDecade           object
# Race1               object
# Education           object
# MaritalStatus       object
# HHIncome            object
# HomeOwn             object
# Work                object
# BMI_WHO             object
# Diabetes            object
# HealthGen           object
# ...

# %%
df2.head()
# Out:
#    Age  HHIncomeMid  Poverty  HomeRooms     Weight      Height        BMI      Pulse    BPSysAve   BPDiaAve      BPSys1     BPDia1      BPSys2     BPDia2      BPSys3     BPDia3  DirectChol  TotChol   UrineVol1  UrineFlow1  DaysPhysHlthBad  DaysMentHlthBad  SleepHrsNight  Gender AgeDecade  Race1    Education MaritalStatus     HHIncome HomeOwn        Work       BMI_WHO Diabetes  HealthGen SleepTrouble PhysActive Smoke100   Smoke100n
# 0   28     100000.0     5.00        5.0  61.000000  161.800000  23.300000  82.000000  121.000000  79.000000  124.000000  78.000000  124.000000  74.000000  118.000000  84.000000    2.790000  4.14000  215.000000    3.909000         0.000000         3.000000       7.000000  female     20-29  White  CollegeGrad       Married   more 99999     Own     Working  18.5_to_24.9       No      Vgood           No        Yes       No  Non-Smoker
# ...

# %%
#value counts for variable
df2["Gender"].value_counts()
# Out:
# female    5020
# male      4980
# Name: Gender, dtype: int64

# %%
#creating dummy variable for object dtype
for x in ['Gender']:
    df2[x] = df2[x].apply(lambda x: 0 if x == str('male') 
                                else 1)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2["AgeDecade"].value_counts()
# Out:
#  40-49    1731
#  0-9      1391
#  10-19    1374
#  20-29    1356
#  30-39    1338
#  50-59    1304
#  60-69     919
#  70+       587
# Name: AgeDecade, dtype: int64

# %%
for x in ['AgeDecade']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('0-9') 
            else 2 if x== str('10-19')
            else 3 if x== str('20-29')
            else 4 if x== str('30-39') 
            else 5 if x== str('40-49') 
            else 6 if x== str('50-59')
            else 7 if x== str('60-69')
            else 8 if x== str('70+')
            else 9)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["Race1"].value_counts()
# Out:
# White       6372
# Black       1197
# Mexican     1015
# Other        806
# Hispanic     610
# Name: Race1, dtype: int64

# %%
for x in ['Race1']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('White') 
            else 2 if x== str('Black')
            else 3 if x== str('Mexican')
            else 4 if x== str('Hispanic') 
            else 5 if x== str('Other') 
            else 6)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["Education"].value_counts()
# Out:
# SomeCollege    5046
# CollegeGrad    2098
# HighSchool     1517
# 9_11thGrade     888
# 8thGrade        451
# Name: Education, dtype: int64

# %%
for x in ['Education']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('8thGrade') 
            else 2 if x== str('9_11thGrade')
            else 3 if x== str('HighSchool')
            else 4 if x== str('SomeCollege') 
            else 5 if x== str('CollegeGrad') 
            else 6)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["MaritalStatus"].value_counts()
# Out:
# Married         6714
# NeverMarried    1380
# Divorced         707
# LivePartner      560
# Widowed          456
# Separated        183
# Name: MaritalStatus, dtype: int64

# %%
for x in ['MaritalStatus']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('Married') 
            else 2 if x== str('NeverMarried')
            else 3 if x== str('Divorced')
            else 4 if x== str('LivePartner') 
            else 5 if x== str('Widowed') 
            else 6 if x== str('Separated')
            else 7)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["HHIncome"].value_counts()
# Out:
# more 99999     3031
# 75000-99999    1084
# 25000-34999     958
# 35000-44999     863
# 45000-54999     784
# 55000-64999     621
# 20000-24999     617
# 10000-14999     543
# 15000-19999     527
# 65000-74999     526
#  5000-9999      254
#  0-4999         192
# Name: HHIncome, dtype: int64

# %%
for x in ['HHIncome']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('0-4999') 
            else 2 if x== str('5000-9999')
            else 3 if x== str('10000-14999')
            else 4 if x== str('15000-19999') 
            else 5 if x== str('20000-24999') 
            else 6 if x== str('25000-34999')
            else 7 if x== str('35000-44999')
            else 8 if x== str('45000-54999')
            else 9 if x== str('55000-64999')
            else 10 if x== str('65000-74999')
            else 11 if x== str('75000-99999') 
            else 12 if x== str('more 99999')
            else 13)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["HomeOwn"].value_counts()
# Out:
# Own      6488
# Rent     3287
# Other     225
# Name: HomeOwn, dtype: int64

# %%
for x in ['HomeOwn']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('Own') 
            else 2 if x== str('Rent')
            else 3 if x== str('Other')
            else 4 if x== str('15000-19999') 
            else 5)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["Work"].value_counts()
# Out:
# Working       6842
# NotWorking    2847
# Looking        311
# Name: Work, dtype: int64

# %%
for x in ['Work']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('Working') 
            else 2 if x== str('NotWorking')
            else 3 if x== str('Looking')
            else 4)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["BMI_WHO"].value_counts()
# Out:
# 18.5_to_24.9    3308
# 30.0_plus       2751
# 25.0_to_29.9    2664
# 12.0_18.5       1277
# Name: BMI_WHO, dtype: int64

# %%
for x in ['BMI_WHO']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('12.0_18.5') 
            else 2 if x== str('18.5_to_24.9')
            else 3 if x== str('25.0_to_29.9')
            else 4 if x== str('30.0_plus') 
            else 5)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["Diabetes"].value_counts()
# Out:
# No     9240
# Yes     760
# Name: Diabetes, dtype: int64

# %%
for x in ['Diabetes', 'SleepTrouble','PhysActive','Smoke100']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('Yes') 
            else 2 if x== str('No')
            else 3)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["HealthGen"].value_counts()
# Out:
# Good         5417
# Vgood        2508
# Fair         1010
# Excellent     878
# Poor          187
# Name: HealthGen, dtype: int64

# %%
for x in ['HealthGen']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('Poor') 
            else 2 if x== str('Fair')
            else 3 if x== str('Good')
            else 4 if x== str('Vgood')
            else 5 if x== str('Excellent')
            else 6)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2["Smoke100n"].value_counts()
# Out:
# Non-Smoker    6789
# Smoker        3211
# Name: Smoke100n, dtype: int64

# %%
for x in ['Smoke100n']:
    df2[x] = df2[x].apply(lambda x: 1 if x == str('Smoker') 
            else 2 if x== str('Non-Smoker')
            else 3)
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.dtypes
# Out:
# Age                  int64
# HHIncomeMid        float64
# Poverty            float64
# HomeRooms          float64
# Weight             float64
# Height             float64
# BMI                float64
# Pulse              float64
# BPSysAve           float64
# BPDiaAve           float64
# BPSys1             float64
# BPDia1             float64
# BPSys2             float64
# BPDia2             float64
# BPSys3             float64
# BPDia3             float64
# DirectChol         float64
# TotChol            float64
# UrineVol1          float64
# UrineFlow1         float64
# DaysPhysHlthBad    float64
# DaysMentHlthBad    float64
# SleepHrsNight      float64
# Gender               int64
# AgeDecade            int64
# Race1                int64
# Education            int64
# MaritalStatus        int64
# HHIncome             int64
# HomeOwn              int64
# Work                 int64
# BMI_WHO              int64
# Diabetes             int64
# HealthGen            int64
# ...

# %%
df2.head()
# Out:
#    Age  HHIncomeMid  Poverty  HomeRooms     Weight      Height        BMI      Pulse    BPSysAve   BPDiaAve      BPSys1     BPDia1      BPSys2     BPDia2      BPSys3     BPDia3  DirectChol  TotChol   UrineVol1  UrineFlow1  DaysPhysHlthBad  DaysMentHlthBad  SleepHrsNight  Gender  AgeDecade  Race1  Education  MaritalStatus  HHIncome  HomeOwn  Work  BMI_WHO  Diabetes  HealthGen  SleepTrouble  PhysActive  Smoke100  Smoke100n
# 0   28     100000.0     5.00        5.0  61.000000  161.800000  23.300000  82.000000  121.000000  79.000000  124.000000  78.000000  124.000000  74.000000  118.000000  84.000000    2.790000  4.14000  215.000000    3.909000         0.000000         3.000000       7.000000       1          9      1          5              1        12        1     1        2         2          4             2           1         2          2
# ...

# %%
import matplotlib as plt
import seaborn as sns

# %%
df.hist(column = 'Age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a252fca10>]],
#       dtype=object)

# %%
df.hist(column = 'DiabetesAge')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2651bb50>]],
#       dtype=object)

# %%
df.hist(column = 'BMI')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2648d550>]],
#       dtype=object)

# %%
df.boxplot('Poverty', by ='Diabetes')

# %%
df.boxplot('BMI', by ='AgeDecade')

# %%
df.boxplot('BMI', by ='Diabetes')

# %%
df.boxplot('BMI', by ='Race1')

# %%
((df2.isnull().sum())/10000)*100
# Out:
# Age                0.0
# HHIncomeMid        0.0
# Poverty            0.0
# HomeRooms          0.0
# Weight             0.0
# Height             0.0
# BMI                0.0
# Pulse              0.0
# BPSysAve           0.0
# BPDiaAve           0.0
# BPSys1             0.0
# BPDia1             0.0
# BPSys2             0.0
# BPDia2             0.0
# BPSys3             0.0
# BPDia3             0.0
# DirectChol         0.0
# TotChol            0.0
# UrineVol1          0.0
# UrineFlow1         0.0
# DaysPhysHlthBad    0.0
# DaysMentHlthBad    0.0
# SleepHrsNight      0.0
# Gender             0.0
# AgeDecade          0.0
# Race1              0.0
# Education          0.0
# MaritalStatus      0.0
# HHIncome           0.0
# HomeOwn            0.0
# Work               0.0
# BMI_WHO            0.0
# Diabetes           0.0
# HealthGen          0.0
# SleepTrouble       0.0
# PhysActive         0.0
# Smoke100           0.0
# Smoke100n          0.0
# dtype: float64

# %%
df2.head()
# Out:
#    Age  HHIncomeMid  Poverty  HomeRooms     Weight      Height        BMI      Pulse    BPSysAve   BPDiaAve      BPSys1     BPDia1      BPSys2     BPDia2      BPSys3     BPDia3  DirectChol  TotChol   UrineVol1  UrineFlow1  DaysPhysHlthBad  DaysMentHlthBad  SleepHrsNight  Gender  AgeDecade  Race1  Education  MaritalStatus  HHIncome  HomeOwn  Work  BMI_WHO  Diabetes  HealthGen  SleepTrouble  PhysActive  Smoke100  Smoke100n
# 0   28     100000.0     5.00        5.0  61.000000  161.800000  23.300000  82.000000  121.000000  79.000000  124.000000  78.000000  124.000000  74.000000  118.000000  84.000000    2.790000  4.14000  215.000000    3.909000         0.000000         3.000000       7.000000       1          9      1          5              1        12        1     1        2         2          4             2           1         2          2
# ...

# %%
# Import Python Libraries
import pandas as pd
import numpy as np
import datetime 
# plotting
import matplotlib as mpl
# machline learning package 
import sklearn as skl
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df_numeric.columns
# Out:
# Index(['ID', 'Age', 'AgeMonths', 'HHIncomeMid', 'Poverty', 'HomeRooms',
#        'Weight', 'Length', 'HeadCirc', 'Height', 'BMI', 'Pulse', 'BPSysAve',
#        'BPDiaAve', 'BPSys1', 'BPDia1', 'BPSys2', 'BPDia2', 'BPSys3', 'BPDia3',
#        'Testosterone', 'DirectChol', 'TotChol', 'UrineVol1', 'UrineFlow1',
#        'UrineVol2', 'UrineFlow2', 'DiabetesAge', 'DaysPhysHlthBad',
#        'DaysMentHlthBad', 'nPregnancies', 'nBabies', 'Age1stBaby',
#        'SleepHrsNight', 'PhysActiveDays', 'TVHrsDayChild', 'CompHrsDayChild',
#        'AlcoholDay', 'AlcoholYear', 'SmokeAge', 'AgeFirstMarij', 'AgeRegMarij',
#        'SexAge', 'SexNumPartnLife', 'SexNumPartYear'],
#       dtype='object')

# %%
#Scatter Plot Matrix of Selected Continous features 
sns.set(style="ticks")
sns.pairplot(df_numeric[['Weight','Height','BMI','DiabetesAge','SleepHrsNight',
                        'PhysActiveDays','AlcoholYear', 'SmokeAge']],palette = 'Set1')
plt.savefig(r'/Users/daniellebeddoe/Desktop/UofHart/QNT755/SPM.png')
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df.columns
# Out:
# Index(['SurveyYr', 'ID', 'Gender', 'Age', 'AgeDecade', 'AgeMonths', 'Race1',
#        'Race3', 'Education', 'MaritalStatus', 'HHIncome', 'HHIncomeMid',
#        'Poverty', 'HomeRooms', 'HomeOwn', 'Work', 'Weight', 'Length',
#        'HeadCirc', 'Height', 'BMI', 'BMICatUnder20yrs', 'BMI_WHO', 'Pulse',
#        'BPSysAve', 'BPDiaAve', 'BPSys1', 'BPDia1', 'BPSys2', 'BPDia2',
#        'BPSys3', 'BPDia3', 'Testosterone', 'DirectChol', 'TotChol',
#        'UrineVol1', 'UrineFlow1', 'UrineVol2', 'UrineFlow2', 'Diabetes',
#        'DiabetesAge', 'HealthGen', 'DaysPhysHlthBad', 'DaysMentHlthBad',
#        'LittleInterest', 'Depressed', 'nPregnancies', 'nBabies', 'Age1stBaby',
#        'SleepHrsNight', 'SleepTrouble', 'PhysActive', 'PhysActiveDays',
#        'TVHrsDay', 'CompHrsDay', 'TVHrsDayChild', 'CompHrsDayChild',
#        'Alcohol12PlusYr', 'AlcoholDay', 'AlcoholYear', 'SmokeNow', 'Smoke100',
#        'Smoke100n', 'SmokeAge', 'Marijuana', 'AgeFirstMarij', 'RegularMarij',
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#define features selected for modeling Split into train test 50/50

X = df2[['Age','HHIncomeMid', 'Poverty', 'HomeRooms',
       'Weight', 'Height', 'BMI', 'Pulse', 'BPSysAve',
       'BPDiaAve', 'BPSys1', 'BPDia1', 'BPSys2', 'BPDia2', 'BPSys3', 'BPDia3',
        'DirectChol', 'TotChol', 'UrineVol1', 'UrineFlow1',
        'DaysPhysHlthBad',
       'DaysMentHlthBad','SleepHrsNight',
        'Gender', 'AgeDecade', 'Race1', 'Education',
       'MaritalStatus', 'HHIncome', 'HomeOwn', 'Work',
       'BMI_WHO', 'HealthGen',
       'SleepTrouble', 'PhysActive','Smoke100', 'Smoke100n']]

y =  df2['Diabetes']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
#Decision Tree Pruned to 4 levels
dtree = DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
#Decision Tree visulation
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot
import pydotplus

features = list(df2[['Age','HHIncomeMid', 'Poverty', 'HomeRooms',
       'Weight', 'Height', 'BMI', 'Pulse', 'BPSysAve',
       'BPDiaAve', 'BPSys1', 'BPDia1', 'BPSys2', 'BPDia2', 'BPSys3', 'BPDia3',
        'DirectChol', 'TotChol', 'UrineVol1', 'UrineFlow1',
        'DaysPhysHlthBad',
       'DaysMentHlthBad','SleepHrsNight',
        'Gender', 'AgeDecade', 'Race1', 'Education',
       'MaritalStatus', 'HHIncome', 'HomeOwn', 'Work',
       'BMI_WHO', 'HealthGen',
       'SleepTrouble', 'PhysActive','Smoke100', 'Smoke100n']])
# Out:
# /Users/daniellebeddoe/opt/anaconda3/lib/python3.7/site-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydotplus.graphviz.graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())

# %%
predictions_dtree = dtree.predict(X_test)

# %%
#Classification Report to check predictions
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.62      0.11      0.18       380
#            2       0.93      0.99      0.96      4620
#
#     accuracy                           0.93      5000
#    macro avg       0.77      0.55      0.57      5000
# weighted avg       0.91      0.93      0.90      5000

# %%
print("Accuracy on test data: {:.2f}".format(dtree.score(X_test, y_test)))
print("Dtree train accuracy: %0.3f" % dtree.score(X_train, y_train))
print("Dtree test accuracy: %0.3f" % dtree.score(X_test, y_test))
# Out:
# Accuracy on test data: 0.93
# Dtree train accuracy: 0.931
# Dtree test accuracy: 0.927

# %%
#plot confusion matrix
from sklearn.metrics import plot_confusion_matrix

classifier = dtree.fit(X_train, y_train)

class_names = df2['Diabetes']

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix - Decision Tree", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(classifier, X_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize, values_format='.2g')
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)
    
plt.tight_layout()   
plt.show()
# Out:
# Confusion matrix, without normalization
# [[  40  340]
#  [  25 4595]]
# Normalized confusion matrix - Decision Tree
# [[0.11 0.89]
#  [0.01 0.99]]

# %%
feature_importances = pd.DataFrame(dtree.feature_importances_, index = X_train.columns,
                                    columns=['importance'])
feature_importances.sort_values(by = 'importance', ascending=False)
# Out:
#                  importance
# Age                0.394349
# HealthGen          0.210103
# BMI                0.090535
# TotChol            0.087814
# BPDia1             0.068977
# BPSys3             0.039038
# BPDia3             0.033737
# Height             0.032596
# BPSys1             0.031541
# Weight             0.011310
# Race1              0.000000
# Education          0.000000
# MaritalStatus      0.000000
# Smoke100           0.000000
# HHIncome           0.000000
# HomeOwn            0.000000
# Work               0.000000
# Gender             0.000000
# BMI_WHO            0.000000
# PhysActive         0.000000
# SleepTrouble       0.000000
# AgeDecade          0.000000
# UrineVol1          0.000000
# SleepHrsNight      0.000000
# DaysMentHlthBad    0.000000
# DaysPhysHlthBad    0.000000
# UrineFlow1         0.000000
# HHIncomeMid        0.000000
# DirectChol         0.000000
# BPDia2             0.000000
# BPSys2             0.000000
# BPDiaAve           0.000000
# ...
